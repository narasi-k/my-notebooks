# %% [markdown]
# <a href="https://colab.research.google.com/github/narasi-k/my-notebooks/blob/main/my_first_jupyter_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install saspy
# Out:
# Collecting saspy
#   Downloading saspy-5.108.3-py3-none-any.whl.metadata (3.9 kB)
# Downloading saspy-5.108.3-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: saspy
# Successfully installed saspy-5.108.3

# %%
import os
import saspy

saspy_dir = os.path.dirname(saspy.__file__)
# Out:
# /usr/local/lib/python3.12/dist-packages/saspy/sascfg_personal.py

# %%
from google.colab import drive
drive.mount('/content/drive')
